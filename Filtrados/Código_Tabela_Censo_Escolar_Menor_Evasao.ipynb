# %%
import pandas as pd

censo_escolar = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Cleaning/src/Datas/Tabela_censo_escolar_2024.csv', sep=';')
evasao_aproveitamento = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Table_Relationships/src/Datas/menores_taxas_evasao_e_reprovacao_2024.csv', sep=';')

menor_evasao_filtrado = evasao_aproveitamento['codigo_escola'].unique()

tabela_censo_escolar_menor_evasao = censo_escolar[censo_escolar['CO_ENTIDADE'].isin(menor_evasao_filtrado)]

# tabela_censo_escolar_menor_evasao.to_csv('Tabela_Censo_Escolar_Menor_Evasao_2024.csv', sep=';', index=False)
