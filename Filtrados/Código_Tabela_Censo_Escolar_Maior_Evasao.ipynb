# %%
import pandas as pd

censo_escolar = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Cleaning/src/Datas/Tabela_censo_escolar_2024.csv', sep=';')
evasao_reprovacao = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Cleaning/src/Datas/Maiores_Taxas_Evasao_e_Reprovacao_2024.csv')  

maior_evasao_filtrado = evasao_reprovacao['codigo_escola'].unique()

tabela_censo_escolar_maior_evasao = censo_escolar[censo_escolar['CO_ENTIDADE'].isin(maior_evasao_filtrado)]

# tabela_censo_escolar_maior_evasao.to_csv('Tabela_Censo_Escolar_Maior_Evasao_2024.csv', sep=';', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       2
#       3 censo_escolar = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Cleaning/src/Datas/Tabela_censo_escolar_2024.csv', sep=';')
#       4 evasao_reprovacao = pd.read_csv('https://raw.githubusercontent.com/MarcilioFilh0/Data_Analysis_Education/refs/heads/Data_Cleaning/src/Datas/Maiores_Taxas_Evasao_e_Reprovacao_2024.csv')
#
# ModuleNotFoundError: No module named 'pandas'
